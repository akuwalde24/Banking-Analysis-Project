# %% [markdown]
# <a href="https://colab.research.google.com/github/akuwalde24/Banking-Analysis-Project/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Banking Analysis**

# %%
#importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#importing banking_clients file
df = pd.read_csv('/content/drive/MyDrive/Project_1(Banking)/banking-clients.csv')
df.head(5)
# Out:
#   Client ID             Name  Age  Location ID Joined Bank   Banking Contact  \
# 0  IND81288    Raymond Mills   24        34324  06-05-2019    Anthony Torres
# 1  IND65833    Julia Spencer   23        42205  10-12-2001  Jonathan Hawkins
# 2  IND47499   Stephen Murray   27         7314  25-01-2010     Anthony Berry
# 3  IND72498   Virginia Garza   40        34594  28-03-2019        Steve Diaz
# 4  IND60181  Melissa Sanders   46        41269  20-07-2012        Shawn Long
#
#   Nationality            Occupation Fee Structure Loyalty Classification  ...  \
# 0    American  Safety Technician IV          High                   Jade  ...
# 1     African   Software Consultant          High                   Jade  ...
# 2    European    Help Desk Operator          High                   Gold  ...
# 3    American          Geologist II           Mid                 Silver  ...
# 4    American   Assistant Professor           Mid               Platinum  ...
#
# ...

# %%
df.shape
# Out:
# (3000, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Client ID                 3000 non-null   object
#  1   Name                      3000 non-null   object
#  2   Age                       3000 non-null   int64
#  3   Location ID               3000 non-null   int64
#  4   Joined Bank               3000 non-null   object
#  5   Banking Contact           3000 non-null   object
#  6   Nationality               3000 non-null   object
#  7   Occupation                3000 non-null   object
#  8   Fee Structure             3000 non-null   object
#  9   Loyalty Classification    3000 non-null   object
#  10  Estimated Income          3000 non-null   float64
#  11  Superannuation Savings    3000 non-null   float64
#  12  Amount of Credit Cards    3000 non-null   int64
# ...

# %%
# Generate descriptive statistics for the dataframe
df.describe()
# Out:
#                Age   Location ID  Estimated Income  Superannuation Savings  \
# count  3000.000000   3000.000000       3000.000000             3000.000000
# mean     51.039667  21563.323000     171305.034263            25531.599673
# std      19.854760  12462.273017     111935.808209            16259.950770
# min      17.000000     12.000000      15919.480000             1482.030000
# 25%      34.000000  10803.500000      82906.595000            12513.775000
# 50%      51.000000  21129.500000     142313.480000            22357.355000
# 75%      69.000000  32054.500000     242290.305000            35464.740000
# max      85.000000  43369.000000     522330.260000            75963.900000
#
#        Amount of Credit Cards  Credit Card Balance    Bank Loans  \
# count             3000.000000          3000.000000  3.000000e+03
# mean                 1.463667          3176.206943  5.913862e+05
# std                  0.676387          2497.094709  4.575570e+05
# ...

# %%
#checking count of null values
df.isnull().sum()
# Out:
# Client ID                   0
# Name                        0
# Age                         0
# Location ID                 0
# Joined Bank                 0
# Banking Contact             0
# Nationality                 0
# Occupation                  0
# Fee Structure               0
# Loyalty Classification      0
# Estimated Income            0
# Superannuation Savings      0
# Amount of Credit Cards      0
# Credit Card Balance         0
# Bank Loans                  0
# Bank Deposits               0
# Checking Accounts           0
# Saving Accounts             0
# Foreign Currency Account    0
# Business Lending            0
# Properties Owned            0
# Risk Weighting              0
# BRId                        0
# GenderId                    0
# IAId                        0
# Income Band                 0
# dtype: int64

# %%
#Replace numeric codes with labels in GenderId
df['GenderId'].value_counts() #count the value
df['GenderId'] = df['GenderId'].replace({1: 'Male', 2: 'Female'}) #replace
df['GenderId'].value_counts() #Check if change or not
# Out:
# GenderId
# Female    1512
# Male      1488
# Name: count, dtype: int64

# %%
#convert dtype of date
df['Joined Bank'] = pd.to_datetime(df['Joined Bank'], dayfirst=True)
print(df['Joined Bank'].dtype)

#or
#df['Joined Bank'] = pd.to_datetime(df['Joined Bank'], format='%d-%m-%Y')
#print(df['Joined Bank'].dtype)
# Out:
# datetime64[ns]

# %%
#make bands
#bining Estimated Income into low, med, high
bins = [0, 100000, 300000, float('inf')]
labels = ['Low', 'Med', 'High']

df['Income Band'] = pd.cut(df['Estimated Income'], bins=bins, labels=labels, right=False)

# %%
df['Income Band'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Income Band'>

# %% [markdown]
# * Majority of clients fall into Medium income band.
# * A smaller percentage of clients are High-income, representing potential premium customers.
# * Insight: Bank can customize offers based on income tiers.

# %%
# Examine the distribution of unique cataegories in categorical columns
categorical_cols = df[["BRId", "GenderId", "IAId", "Amount of Credit Cards", "Nationality", "Occupation", "Fee Structure", "Loyalty Classification", "Properties Owned", "Risk Weighting", "Income Band"]].columns

for col in categorical_cols:
  print("Value Counts for '{col}':")
  display(df[col].value_counts())
# Out:
# Value Counts for '{col}':
# BRId
# 3    1352
# 1     660
# 2     495
# 4     493
# Name: count, dtype: int64
# Value Counts for '{col}':
# GenderId
# Female    1512
# Male      1488
# Name: count, dtype: int64
# Value Counts for '{col}':
# IAId
# 1     177
# 2     177
# 3     177
# 4     177
# 8     177
# 9     176
# 13    176
# 12    176
# 10    176
# 11    176
# 14    176
# 15    176
# 6      89
# 5      89
# 7      89
# 16     88
# 17     88
# 18     88
# 19     88
# 20     88
# 21     88
# 22     88
# Name: count, dtype: int64
# Value Counts for '{col}':
# Amount of Credit Cards
# 1    1922
# 2     765
# 3     313
# Name: count, dtype: int64
# Value Counts for '{col}':
# Nationality
# European      1309
# Asian          754
# American       507
# Australian     254
# African        176
# Name: count, dtype: int64
# Value Counts for '{col}':
# Occupation
# Associate Professor             28
# Structural Analysis Engineer    28
# Recruiter                       25
# ...

# %% [markdown]
# Univariate Analysis

# %%
for i, predictor in enumerate(df[["BRId", "GenderId", "IAId", "Amount of Credit Cards", "Nationality", "Occupation", "Fee Structure", "Loyalty Classification", "Properties Owned", "Risk Weighting", "Income Band"]].columns):
    plt.figure(i)
    sns.countplot(data=df, x=predictor)

# %% [markdown]
# Bivariate Analysis

# %%
#on the basis of nationality
for i, predictor in enumerate(df[["BRId", "GenderId", "IAId", "Amount of Credit Cards", "Nationality", "Occupation", "Fee Structure", "Loyalty Classification", "Properties Owned", "Risk Weighting", "Income Band"]].columns):
    plt.figure(i)
    sns.countplot(data=df, x=predictor, hue='Nationality')

# %%
#on the basis of GenderId
for i, predictor in enumerate(df[["BRId", "GenderId", "IAId", "Amount of Credit Cards", "Nationality", "Occupation", "Fee Structure", "Loyalty Classification", "Properties Owned", "Risk Weighting", "Income Band"]].columns):
    plt.figure(i)
    sns.countplot(data=df, x=predictor, hue='GenderId')

# %%
# Histplot of value counts for different Occupation

for col in categorical_cols:
  if col == "Occupation":
    continue
  plt.figure(figsize=(8,4))
  sns.histplot(df[col])
  plt.title('Histogram of Occupation Count')
  plt.xlabel(col)
  plt.ylabel("Count")
  plt.show()

# %% [markdown]
# Numerical Columns

# %%
# Numerical analysis and exploration
numerical_cols = ['Estimated Income', 'Superannuation Savings', 'Credit Card Balance', 'Bank Loans', 'Bank Deposits', 'Checking Accounts', 'Saving Accounts', 'Foreign Currency Account', 'Business Lending']

# Univariate analysis and visualization
plt.figure(figsize=(15,15))

for i,col in enumerate(numerical_cols):
  plt.subplot(3,3,i+1)
  sns.histplot(df[col],kde=True)
  plt.title(col)
plt.show()

# %% [markdown]
# * Estimated Income is right-skewed, with a few high-income clients.
# * Bank Deposits, Checking Accounts, Saving Accounts show some extreme outliers → some clients maintain very high balances.
# * Credit Card Balance & Loans are moderately skewed, indicating that most clients have low-to-medium debt.

# %%
# Correlation=Relationship between numerical variables
# Select numerical columns for correlation analysis
numerical_cols = ['Estimated Income', 'Superannuation Savings', 'Credit Card Balance', 'Bank Loans', 'Bank Deposits', 'Checking Accounts', 'Saving Accounts', 'Foreign Currency Account', 'Business Lending']

correlation_matrix = df[numerical_cols].corr() #This calculates relation between every pair of numerical columns

#create heatmap to show correlation matrix
plt.figure(figsize=(6,6))
sns.heatmap(correlation_matrix, annot=True, cmap='crest', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

#or
#numeric_df = df.select_dtypes(include=['number'])
#sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')

# %% [markdown]
# 1) The strongest positive correlations occur among:
# * Bank Deposits ↔ Checking Accounts, Saving Accounts, Foreign Currency Account
# => Customers maintaining high balances in one account type often hold substantial funds in other accounts.
#
# * Estimated Income ↔ Bank Deposits
#
#     => Higher-income clients generally maintain larger deposits.
#
# 2) Weak or negligible correlation between Credit Card Balance & Bank Deposits → clients with high deposits do not necessarily have high credit card debt.

# %%
pairs_to_plot = [
    ('Bank Deposits', 'Saving Accounts'),
    ('Checking Accounts', 'Saving Accounts'),
    ('Checking Accounts', 'Foreign Currency Account'),
    ('Age', 'Superannuation Savings'),
    ('Estimated Income', 'Checking Accounts'),
    ('Bank Loans', 'Credit Card Balance'),
    ('Business Lending', 'Bank Loans'),
]

# Create a 3x3 grid of subplots
fig, axes = plt.subplots(3, 3, figsize=(18, 15))
axes = axes.flatten()  # Flatten 2D array of axes to 1D for easy looping

for i, (x_col, y_col) in enumerate(pairs_to_plot):
    sns.regplot(
        data=df,
        x=x_col,
        y=y_col,
        ax=axes[i],
        scatter_kws={'alpha': 0.4},
        line_kws={'color': 'red'}
    )
    axes[i].set_title(f'{x_col} vs {y_col}', fontsize=12)
    axes[i].set_xlabel(x_col, fontsize=10)
    axes[i].set_ylabel(y_col, fontsize=10)


# Hide any unused subplot boxes (since 3x3=9 but we have only 7 plots)
[i.remove() for i in axes.flat[len(pairs_to_plot):]]

plt.tight_layout()
plt.show()

# %% [markdown]
# * A positive slope between Bank Deposits and Saving Accounts → customers with higher savings also tend to have higher deposits.
# * A negative slope (if any) → an inverse relationship, e.g., higher loans might reduce deposits.
# * A flat line → weak or no relationship.

# %% [markdown]
# **Deposits and Savings Behavior**
#
# The high correlation between Bank Deposits and Saving Accounts suggests that these may either measure overlapping financial behavior (e.g., total funds a customer keeps in the bank) or that people who actively deposit funds also tend to maintain or grow savings balances.
#
# **Income, Age, and Accumulation**
#
# Moderate correlations of Age and Estimated Income with various balances (Superannuation, Savings, Checking) reflect a common financial lifecycle trend: higher income earners and older individuals often accumulate more savings, retirement funds, and may carry higher credit card balances or loans.
#
# **Low Correlation with Properties Owned**
#
# Property ownership may depend on external factors (location, real estate market conditions, inheritance, etc.) that are not captured by these particular banking variables. Hence, we see weaker correlations here.
#
# **Business vs. Personal Banking**
#
# Business Lending’s moderate link to Bank Loans suggests some customers may have both personal and business debts. However, business lending is relatively uncorrelated with other deposit or property-related metrics, indicating it may serve a distinct subset of customers or needs.

# %%
# Boxplot for outliers which visualizes:
#Median (middle value), Quartiles (spread of data), Outliers (points outside normal range)
#Boxplot= Outliers Extreme highs/lows
sns.boxplot(x=df['Bank Deposits'])
plt.title('Bank Deposits Outlier Analysis')
plt.show()

# %% [markdown]
# Boxplot of Bank Deposits shows extremely high deposits for some clients → these are high-value clients, could be targets for premium services.

# %% [markdown]
# Categorical Columns

# %%
# Frequency of nationality
df['Nationality'].value_counts().plot(kind='bar')
plt.title('Client Count by Nationality')
plt.show()

# %% [markdown]
# Majority of clients belong to a particular nationality likely American.

# %%
# Loyalty vs Saving Accounts
sns.boxplot(x='Loyalty Classification', y='Saving Accounts', data=df)
plt.title('Saving Accounts by Loyalty Classification')
plt.show()

# %% [markdown]
# Saving Accounts vs Loyalty Classification: higher loyalty clients generally have higher saving account balances.

# %%
# Gender vs Bank Deposits
sns.barplot(x='GenderId', y='Bank Deposits', data=df)
plt.title('Average Bank Deposits by Gender')
plt.show()

# %% [markdown]
# Average Bank Deposits by Gender: males tend to maintain slightly higher deposits than females.

# %% [markdown]
# Date Column

# %%
#growth trend of bank’s customer base over time.
df['Join_Year'] = df['Joined Bank'].dt.year
df['Join_Year'].value_counts().sort_index().plot(kind='bar')
plt.title('Clients Joined per Year')
# Out:
# Text(0.5, 1.0, 'Clients Joined per Year')

# %% [markdown]
# Bank has expanded client base over recent years, possibly due to new products or marketing campaigns. strong growth in the year 2020.

# %% [markdown]
# # **Insights of EDA**
#
# The analysis shows that high-income and loyal clients tend to maintain larger balances across multiple account types, with strong correlations between Bank Deposits, Checking Accounts, Saving Accounts, and Foreign Currency Account, while the bank’s customer base has steadily grown over the years, with demographic differences in gender and nationality influencing account behaviors. Outliers highlight high-value clients, presenting opportunities for targeted premium services.
